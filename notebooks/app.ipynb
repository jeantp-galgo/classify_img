# %%
import anthropic
client = anthropic.Anthropic()

# %%
try:
    response = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=10,
        messages=[{"role": "user", "content": "Di solo: OK"}]
    )
    print(f"✓ API responde correctamente: {response.content[0].text.strip()}")
except anthropic.AuthenticationError:
    print("❌ Key inválida o revocada")
except anthropic.PermissionDeniedError:
    print("❌ Sin permisos para usar este modelo")
except Exception as e:
    print(f"❌ Error inesperado: {e}")
# Out:
# ❌ Error inesperado: Error code: 529 - {'type': 'error', 'error': {'type': 'overloaded_error', 'message': 'Overloaded'}, 'request_id': 'req_011CYiGxByKNVaS8PS3KQvrg'}

# %%
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 response
#
# NameError: name 'response' is not defined
